# %% [markdown]
# <a href="https://colab.research.google.com/github/NewTAs/ODCuC/blob/main/ICCC_220928_TryAA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import re
import glob
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

import tensorflow as tf

from google.colab import drive
drive.mount('ICCC_DATASET')
# Out:
# Mounted at ICCC_DATASET

# %%
numberOfClass = 10
pictureWeightHeightSize = 112

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        '/content/ICCC_DATASET/MyDrive/ICCC_DATASET/01Train/',
        target_size=(pictureWeightHeightSize, pictureWeightHeightSize),
        batch_size=numberOfClass,
        class_mode='categorical')

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        '/content/ICCC_DATASET/MyDrive/ICCC_DATASET/02Test/',
        target_size=(pictureWeightHeightSize, pictureWeightHeightSize),    
        batch_size=numberOfClass,
        class_mode='categorical')
# Out:
# Found 170 images belonging to 10 classes.
# Found 80 images belonging to 10 classes.

# %%
"""
Recall and Declare Convolutional Neural Network Models.

Using CNN Models: VGG16
"""

from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.applications import Xception

# %%
"""
Learning four models using repetitive statements without interruption.
"""
for i in range(7):
    if i == 0:
        model = VGG16(include_top=True, weights=None, input_shape=(pictureWeightHeightSize, pictureWeightHeightSize, 3), pooling=max, classes=numberOfClass)
    elif i == 1:
        model = ResNet50(include_top=True, weights=None, input_shape=(pictureWeightHeightSize, pictureWeightHeightSize, 3), pooling=max, classes=numberOfClass)
    elif i == 2:
        model = InceptionV3(include_top=True, weights=None, input_shape=(pictureWeightHeightSize, pictureWeightHeightSize, 3), pooling=max, classes=numberOfClass)
    elif i == 3:
        model = MobileNet(include_top=True, weights=None, input_shape=(pictureWeightHeightSize, pictureWeightHeightSize, 3), pooling=max, classes=numberOfClass)
    elif i == 4:
        model = VGG19(include_top=True, weights=None, input_shape=(pictureWeightHeightSize, pictureWeightHeightSize, 3), pooling=max, classes=numberOfClass)
    elif i == 5:
        model = ResNet50V2(include_top=True, weights=None, input_shape=(pictureWeightHeightSize, pictureWeightHeightSize, 3), pooling=max, classes=numberOfClass)
    else:
        model = Xception(include_top=True, weights=None, input_shape=(pictureWeightHeightSize, pictureWeightHeightSize, 3), pooling=max, classes=numberOfClass)
    
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
    model.fit(train_generator, epochs=100, validation_data = test_generator)
        
    score = model.evaluate(test_generator)[1] * 100
    print(f'{i} -- Evaluate -- : {score:.2f}')
    print(score)

    if i == 0:
      model.save("/content/ICCC_DATASET/MyDrive/ICCC_DATASET/Result/ICCC_AA_21_VGG16_Model")
    elif i == 1:
      model.save("/content/ICCC_DATASET/MyDrive/ICCC_DATASET/Result/ICCC_AA_22_ResNet50_Model")
    elif i == 2:
      model.save("/content/ICCC_DATASET/MyDrive/ICCC_DATASET/Result/ICCC_AA_23_InceptionV3_Model")
    elif i == 3:
      model.save("/content/ICCC_DATASET/MyDrive/ICCC_DATASET/Result/ICCC_AA_24_MobileNet_Model")
    elif i == 4:
      model.save("/content/ICCC_DATASET/MyDrive/ICCC_DATASET/Result/ICCC_AA_25_VGG19_Model")
    elif i == 5:
      model.save("/content/ICCC_DATASET/MyDrive/ICCC_DATASET/Result/ICCC_AA_26_ResNet50V2_Model")
    else:
      model.save("/content/ICCC_DATASET/MyDrive/ICCC_DATASET/Result/ICCC_AA_27_Xception_Model")
# Out:
# Epoch 1/100
# 17/17 [==============================] - 172s 10s/step - loss: 2.4055 - accuracy: 0.0882 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 2/100
# 17/17 [==============================] - 1s 79ms/step - loss: 2.3061 - accuracy: 0.0765 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 3/100
# 17/17 [==============================] - 1s 77ms/step - loss: 2.3050 - accuracy: 0.0471 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 4/100
# 17/17 [==============================] - 1s 77ms/step - loss: 2.3037 - accuracy: 0.0765 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 5/100
# 17/17 [==============================] - 1s 76ms/step - loss: 2.3036 - accuracy: 0.0647 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 6/100
# 17/17 [==============================] - 1s 77ms/step - loss: 2.3034 - accuracy: 0.0706 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 7/100
# ...
